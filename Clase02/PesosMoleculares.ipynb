# %%
elementos={'H': [1.008, 'Hydrogen', 'H', -259, -253, 0.09],
 'He': [4.003, 'Helium', 'He', -272, -269, 0.18],
 'Li': [6.941, 'Lithium', 'Li', 180, 1347, 0.53],
 'Be': [9.012, 'Beryllium', 'Be', 1278, 2970, 1.85],
 'B': [10.811, 'Boron', 'B', 2300, 2550, 2.34],
 'C': [12.011, 'Carbon', 'C', 3500, 4827, 2.26],
 'N': [14.007, 'Nitrogen', 'N', -210, -196, 1.25],
 'O': [15.999, 'Oxygen', 'O', -218, -183, 1.43],
 'F': [18.998, 'Fluorine', 'F', -220, -188, 1.7],
 'Ne': [20.18, 'Neon', 'Ne', -249, -246, 0.9],
 'Na': [22.99, 'Sodium', 'Na', 98, 883, 0.97],
 'Mg': [24.305, 'Magnesium', 'Mg', 639, 1090, 1.74],
 'Al': [26.982, 'Aluminum', 'Al', 660, 2467, 2.7],
 'Si': [28.086, 'Silicon', 'Si', 1410, 2355, 2.33],
 'P': [30.974, 'Phosphorus', 'P', 44, 280, 1.82],
 'S': [32.065, 'Sulfur', 'S', 113, 445, 2.07],
 'Cl': [35.453, 'Chlorine', 'Cl', -101, -35, 3.21],
 'Ar': [39.948, 'Argon', 'Ar', -189, -186, 1.78],
 'K': [39.098, 'Potassium', 'K', 64, 774, 0.86],
 'Ca': [40.078, 'Calcium', 'Ca', 839, 1484, 1.55],
 'Sc': [44.956, 'Scandium', 'Sc', 1539, 2832, 2.99],
 'Ti': [47.867, 'Titanium', 'Ti', 1660, 3287, 4.54],
 'V': [50.942, 'Vanadium', 'V', 1890, 3380, 6.11],
 'Cr': [51.996, 'Chromium', 'Cr', 1857, 2672, 7.19],
 'Mn': [54.938, 'Manganese', 'Mn', 1245, 1962, 7.43],
 'Fe': [55.845, 'Iron', 'Fe', 1535, 2750, 7.87],
 'Co': [58.933, 'Cobalt', 'Co', 1495, 2870, 8.9],
 'Ni': [58.693, 'Nickel', 'Ni', 1453, 2732, 8.9],
 'Cu': [63.546, 'Copper', 'Cu', 1083, 2567, 8.96],
 'Zn': [65.39, 'Zinc', 'Zn', 420, 907, 7.13],
 'Ga': [69.723, 'Gallium', 'Ga', 30, 2403, 5.91],
 'Ge': [72.64, 'Germanium', 'Ge', 937, 2830, 5.32],
 'As': [74.922, 'Arsenic', 'As', 81, 613, 5.72],
 'Se': [78.96, 'Selenium', 'Se', 217, 685, 4.79],
 'Br': [79.904, 'Bromine', 'Br', -7, 59, 3.12],
 'Kr': [83.8, 'Krypton', 'Kr', -157, -153, 3.75],
 'Rb': [85.468, 'Rubidium', 'Rb', 39, 688, 1.63],
 'Sr': [87.62, 'Strontium', 'Sr', 769, 1384, 2.54],
 'Y': [88.906, 'Yttrium', 'Y', 1523, 3337, 4.47],
 'Zr': [91.224, 'Zirconium', 'Zr', 1852, 4377, 6.51],
 'Nb': [92.906, 'Niobium', 'Nb', 2468, 4927, 8.57],
 'Mo': [95.94, 'Molybdenum', 'Mo', 2617, 4612, 10.22],
 'Tc': [98.0, 'Technetium', 'Tc', 2200, 4877, 11.5],
 'Ru': [101.07, 'Ruthenium', 'Ru', 2250, 3900, 12.37],
 'Rh': [102.906, 'Rhodium', 'Rh', 1966, 3727, 12.41],
 'Pd': [106.42, 'Palladium', 'Pd', 1552, 2927, 12.02],
 'Ag': [107.868, 'Silver', 'Ag', 962, 2212, 10.5],
 'Cd': [112.411, 'Cadmium', 'Cd', 321, 765, 8.65],
 'In': [114.818, 'Indium', 'In', 157, 2000, 7.31],
 'Sn': [118.71, 'Tin', 'Sn', 232, 2270, 7.31],
 'Sb': [121.76, 'Antimony', 'Sb', 630, 1750, 6.68],
 'Te': [127.6, 'Tellurium', 'Te', 449, 990, 6.24],
 'I': [126.905, 'Iodine', 'I', 114, 184, 4.93],
 'Xe': [131.293, 'Xenon', 'Xe', -112, -108, 5.9],
 'Cs': [132.906, 'Cesium', 'Cs', 29, 678, 1.87],
 'Ba': [137.327, 'Barium', 'Ba', 725, 1140, 3.59],
 'La': [138.906, 'Lanthanum', 'La', 920, 3469, 6.15],
 'Ce': [140.116, 'Cerium', 'Ce', 795, 3257, 6.77],
 'Pr': [140.908, 'Praseodymium', 'Pr', 935, 3127, 6.77],
 'Nd': [144.24, 'Neodymium', 'Nd', 1010, 3127, 7.01],
 'Pm': [145.0, 'Promethium', 'Pm', 1100, 3000, 7.3],
 'Sm': [150.36, 'Samarium', 'Sm', 1072, 1900, 7.52],
 'Eu': [151.964, 'Europium', 'Eu', 822, 1597, 5.24],
 'Gd': [157.25, 'Gadolinium', 'Gd', 1311, 3233, 7.9],
 'Tb': [158.925, 'Terbium', 'Tb', 1360, 3041, 8.23],
 'Dy': [162.5, 'Dysprosium', 'Dy', 1412, 2562, 8.55],
 'Ho': [164.93, 'Holmium', 'Ho', 1470, 2720, 8.8],
 'Er': [167.259, 'Erbium', 'Er', 1522, 2510, 9.07],
 'Tm': [168.934, 'Thulium', 'Tm', 1545, 1727, 9.32],
 'Yb': [173.04, 'Ytterbium', 'Yb', 824, 1466, 6.9],
 'Lu': [174.967, 'Lutetium', 'Lu', 1656, 3315, 9.84],
 'Hf': [178.49, 'Hafnium', 'Hf', 2150, 5400, 13.31],
 'Ta': [180.948, 'Tantalum', 'Ta', 2996, 5425, 16.65],
 'W': [183.84, 'Tungsten', 'W', 3410, 5660, 19.35],
 'Re': [186.207, 'Rhenium', 'Re', 3180, 5627, 21.04],
 'Os': [190.23, 'Osmium', 'Os', 3045, 5027, 22.6],
 'Ir': [192.217, 'Iridium', 'Ir', 2410, 4527, 22.4],
 'Pt': [195.078, 'Platinum', 'Pt', 1772, 3827, 21.45],
 'Au': [196.967, 'Gold', 'Au', 1064, 2807, 19.32],
 'Hg': [200.59, 'Mercury', 'Hg', -39, 357, 13.55],
 'Tl': [204.383, 'Thallium', 'Tl', 303, 1457, 11.85],
 'Pb': [207.2, 'Lead', 'Pb', 327, 1740, 11.35],
 'Bi': [208.98, 'Bismuth', 'Bi', 271, 1560, 9.75],
 'Po': [209.0, 'Polonium', 'Po', 254, 962, 9.3],
 'At': [210.0, 'Astatine', 'At', 302, 337, 0.0],
 'Rn': [222.0, 'Radon', 'Rn', -71, -62, 9.73],
 'Fr': [223.0, 'Francium', 'Fr', 27, 677, 0.0],
 'Ra': [226.0, 'Radium', 'Ra', 700, 1737, 5.5],
 'Ac': [227.0, 'Actinium', 'Ac', 1050, 3200, 10.07],
 'Th': [232.038, 'Thorium', 'Th', 1750, 4790, 11.72],
 'Pa': [231.036, 'Protactinium', 'Pa', 1568, 0, 15.4],
 'U': [238.029, 'Uranium', 'U', 1132, 3818, 18.95],
 'Np': [237.0, 'Neptunium', 'Np', 640, 3902, 20.2],
 'Pu': [244.0, 'Plutonium', 'Pu', 640, 3235, 19.84],
 'Am': [243.0, 'Americium', 'Am', 994, 2607, 13.67],
 'Cm': [247.0, 'Curium', 'Cm', 1340, 0, 13.5],
 'Bk': [247.0, 'Berkelium', 'Bk', 986, 0, 14.78],
 'Cf': [251.0, 'Californium', 'Cf', 900, 0, 15.1],
 'Es': [252.0, 'Einsteinium', 'Es', 860, 0, 0.0],
 'Fm': [257.0, 'Fermium', 'Fm', 1527, 0, 0.0],
 'Md': [258.0, 'Mendelevium', 'Md', 0, 0, 0.0],
 'No': [259.0, 'Nobelium', 'No', 827, 0, 0.0],
 'Lr': [262.0, 'Lawrencium', 'Lr', 1627, 0, 0.0],
 'Rf': [261.0, 'Rutherfordium', 'Rf', 0, 0, 0.0],
 'Db': [262.0, 'Dubnium', 'Db', 0, 0, 0.0],
 'Sg': [266.0, 'Seaborgium', 'Sg', 0, 0, 0.0],
 'Bh': [264.0, 'Bohrium', 'Bh', 0, 0, 0.0],
 'Hs': [277.0, 'Hassium', 'Hs', 0, 0, 0.0],
 'Mt': [268.0, 'Meitnerium', 'Mt', 0, 0, 0.0]}

# %%
formula="KClO3"
simb=[]
ca=""
cad=""
for x in formula:
    
    if x>="A" and x<="Z":
        simb.append(x)
       
    if x>="a" and x<="z":
       
        s=simb.pop()
        s=s+x
        simb.append(s)
        
    if x>="0" and x<="9" and (ca=="LM" or ca=="Lm"):
        cad=cad+"*"
    if (x>="A" and x<="Z"):
        if ca=="LM":
            cad=cad+"+"
    if x=="(" and ca=="N":
        cad=cad+"+"
    if x>="0" and x<="9" and ca==")":
        cad=cad+"*"
    if (x>="A" and x<="Z") or (x>="a" and x<="z"):
        if ca=="N":
            cad=cad+"+"
    if x>="A" and x<="Z" and ca=="Lm":
        cad=cad+"+"
        
    cad=cad+x
    
    if (x>="A" and x<="Z"):
        ca="LM"
    if (x>="a" and x<="z"):
        ca="Lm"
    if (x>="0" and x<="9"):
        ca="N"
    if x=="(":
        ca="("
    if x==")":
        ca=")"
    

for x in simb:
    peso=str(elementos[x][0])
    cad=cad.replace(x,peso)


PM=eval(cad)
print("El peso molecular de %s es %f"%(formula,PM))
# Out:
# El peso molecular de KClO3 es 122.548000

# %%
str(89)
# Out:
# '89'
